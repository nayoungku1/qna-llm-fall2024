# %% [markdown]
# ### Embeddings
# * 단어별 / 문장별 임베딩 생성 가능
# * 임베딩으로 바꾸는 이유: 질문과 가장 흡사한 문맥(문서)을 찾기 위해 벡터db에 서치를 하는데, 이 DB에는 embedding으로 모든 것이 저장된다.

# %%
from langchain_openai import OpenAIEmbeddings

# %%
model_names = {
    "small": "text-embedding-3-small",
    "large": "text-embedding-3-large",
    "ada": "text-embedding-ada-002",
}

# %%
text = ["삼엽충 화석은 진화론을 뒷받침하고 있나요?"]

# %% [markdown]
# ### text-embedding-3-small

# %%
embedding_model1 = OpenAIEmbeddings(model=model_names["small"])

# %%
embedding = embedding_model1.embed_documents(text)

# %%
len(embedding)
# Out:
# 1

# %%
len(embedding[0])
# Out:
# 1536

# %%
embedding
# Out:
# [[0.050785910338163376,
#   0.041429486125707626,
#   -0.017642322927713394,
#   0.01120844203978777,
#   -0.005462375935167074,
#   8.639506268082187e-05,
#   -0.03620530292391777,
#   0.03652646020054817,
#   0.005344617646187544,
#   -0.030295979231595993,
#   0.010769524611532688,
#   -0.005446318071335554,
#   -0.017128469422459602,
#   0.0379609689116478,
#   0.004498899448662996,
#   -0.0009333677589893341,
#   -0.0718967467546463,
#   0.03836777061223984,
#   -0.024986153468489647,
#   0.026934517547488213,
#   -0.060120925307273865,
#   -0.017963482066988945,
#   -0.01928023248910904,
#   0.02965366281569004,
#   -0.037061724811792374,
#   0.018541567027568817,
#   -0.034385401755571365,
#   0.017492448911070824,
#   0.01995466649532318,
#   -0.06641563773155212,
#   0.025371544063091278,
#   -0.023551644757390022,
#   -0.01124055776745081,
#   -0.020629100501537323,
#   -0.05532495677471161,
#   0.013767006807029247,
#   0.0010832418920472264,
#   -0.040444597601890564,
# ...
